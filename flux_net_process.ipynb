# %%
import os
import glob
import numpy as np
import pandas as pd
import json
import datetime
import math

# importing required modules
from zipfile import ZipFile

# %%
_dir = 'D:/Flux_net/'

# %%
BADM_file = _dir + 'FLX_AA-Flx_BIF_ALL_20200501/FLX_AA-Flx_BIF_HH_20200501.xlsx'

# %%
badm = pd.read_excel(BADM_file)
badm

# %% [markdown]
# ### Site info

# %%
site_list  = list(badm['SITE_ID'].values)

# %%
site_list = list(set(site_list))
site_list.sort()

# %%
len(site_list)

# %%
# site parameters

site_param = ['SITE_NAME','MAP','COUNTRY','IGBP', 'LOCATION_LAT', 'LOCATION_LONG','UTC_OFFSET' ]

# %%
site_info = []
for _site in site_list:
    _data = dict()
    _data['site_id'] = _site
    for _param in site_param:
        _var = badm[(badm['SITE_ID'] == _site)][['VARIABLE','DATAVALUE']]
        _var_ = _var[_var['VARIABLE'] == _param]['DATAVALUE']
        if _var_.empty:
            _data[_param] = -9999
        else:
            _data[_param] = _var_.values[0]
    
    site_info.append(_data)

# %%
pd_site_info = pd.DataFrame(site_info)
pd_site_info

# %%
#pd_site_info.to_csv('site_info.csv', float_format='%.5f', index=False)

# %% [markdown]
# ### Site variables

# %%
_sel_param = ['TA_F','SW_IN_F','VPD_F','RH','WS_F','P','P_F',
             'GPP_NT_VUT_REF', 'GPP_DT_VUT_REF', 'RECO_NT_VUT_REF','RECO_DT_VUT_REF','NEE_VUT_REF'
             ]

# %%
site_vars = []
for _site in site_list:
    params = dict()
    params['site_id'] = _site
    _var = badm[(badm['SITE_ID'] == _site)][['VARIABLE','DATAVALUE']]

    block_start = 0

    for index, row in _var.iterrows():
        if row['VARIABLE'] == 'VAR_INFO_VARNAME':
            
            if block_start == 1:
                print('Err row',row)
            else:
                block_start = 1
                _param = row['DATAVALUE']

            continue
        

        if row['VARIABLE'] == 'VAR_INFO_UNIT':
            
            if block_start == 0:
                print('Err row',row)
            else:
                block_start = 0
                if _param not in _sel_param:
                    continue
                _unit = row['DATAVALUE']
                params[_param] = _unit
    
    site_vars.append(params)

# %%
pd_site_param = pd.DataFrame(site_vars)
pd_site_param

# %%
pd_site_param.iloc[136]

# %%
pd_result = pd.concat([pd_site_info,pd_site_param], axis=1)
pd_result

# %%
pd_site_param[pd_site_param['site_id'] == 'US-Wi0']

# %% [raw]
# # pd_site_param.to_csv('site_vars.csv', float_format='%.5f', index=False)

# %%
pd_result.to_csv('all_sites_param.csv', float_format='%.5f', index=False)

# %% [markdown]
# ### One site US-Wi0 flux net full HH data

# %%
### flux net full data

US_Wi0_file = _dir + 'FLX_US-Wi0_FLUXNET2015_FULLSET_2002-2002_1-4/FLX_US-Wi0_FLUXNET2015_FULLSET_HH_2002-2002_1-4.csv'

data = pd.read_csv(US_Wi0_file, dtype={'TIMESTAMP_START':str, 'TIMESTAMP_END':str})
data

# %%
def create_day(row):
    _str = row['TIMESTAMP_START']
    return _str[:-4]
data['day'] = data.apply (lambda row: create_day(row) , axis=1)

# %%
data['SW_IN_F'].max()

# %% [raw]
# _sel_param = ['TIMESTAMP_START','TIMESTAMP_END','TA_F','SW_IN_F','VPD_F','RH','WS_F','P','P_F',
#              'GPP_NT_VUT_REF', 'GPP_NT_VUT_USTAR50','GPP_NT_VUT_MEAN','GPP_NT_VUT_SE','GPP_NT_VUT_05','GPP_NT_VUT_16','GPP_NT_VUT_25',
#              'GPP_NT_VUT_50', 'GPP_NT_VUT_75', 'GPP_NT_VUT_84','GPP_NT_VUT_95',
#              'GPP_DT_VUT_REF', 'GPP_DT_VUT_USTAR50','GPP_DT_VUT_MEAN','GPP_DT_VUT_SE','GPP_DT_VUT_05','GPP_DT_VUT_16','GPP_DT_VUT_25',
#              'GPP_DT_VUT_50', 'GPP_DT_VUT_75', 'GPP_DT_VUT_84','GPP_DT_VUT_95',
#              'RECO_NT_VUT_REF','RECO_NT_VUT_USTAR50','RECO_NT_VUT_MEAN','RECO_NT_VUT_SE','RECO_NT_VUT_05','RECO_NT_VUT_16','RECO_NT_VUT_25',
#              'RECO_NT_VUT_50', 'RECO_NT_VUT_75', 'RECO_NT_VUT_84', 'RECO_NT_VUT_95',
#              'RECO_DT_VUT_REF','RECO_DT_VUT_USTAR50','RECO_DT_VUT_MEAN','RECO_DT_VUT_SE','RECO_DT_VUT_05','RECO_DT_VUT_16','RECO_DT_VUT_25',
#              'RECO_DT_VUT_50', 'RECO_DT_VUT_75', 'RECO_DT_VUT_84', 'RECO_DT_VUT_95',
#              'NEE_VUT_REF','NEE_VUT_REF_QC','NEE_VUT_REF_RANDUNC','NEE_VUT_REF_RANDUNC_METHOD','NEE_VUT_REF_RANDUNC_N','NEE_VUT_REF_JOINTUNC',
#              'NEE_VUT_USTAR50','NEE_VUT_USTAR50_QC','NEE_VUT_USTAR50_RANDUNC','NEE_VUT_USTAR50_RANDUNC_METHOD','NEE_VUT_USTAR50_RANDUNC_N',
#              'NEE_VUT_USTAR50_JOINTUNC','NEE_VUT_MEAN','NEE_VUT_MEAN_QC','NEE_VUT_SE','NEE_VUT_05','NEE_VUT_16','NEE_VUT_25','NEE_VUT_50',
#              'NEE_VUT_75','NEE_VUT_84','NEE_VUT_95','NEE_VUT_05_QC','NEE_VUT_16_QC','NEE_VUT_25_QC','NEE_VUT_50_QC','NEE_VUT_75_QC',
#              'NEE_VUT_84_QC','NEE_VUT_95_QC',
#              ]

# %% [raw]
# ['TA_F_MDS_QC',
#     'SW_IN_F_MDS_QC',
#
#   'LW_IN_F_MDS_QC',
#   'LW_IN_F_QC',
#   'LW_IN_JSB_QC',
#   'LW_IN_JSB_F_QC',
#   'VPD_F_MDS_QC',
#
#   'CO2_F_MDS_QC',
#   'TS_F_MDS_1_QC',
#   'TS_F_MDS_2_QC',
#   'TS_F_MDS_3_QC',
#   'TS_F_MDS_4_QC',
#   'TS_F_MDS_5_QC',
#   'TS_F_MDS_6_QC',
#   'TS_F_MDS_7_QC',
#   'TS_F_MDS_8_QC',
#   'TS_F_MDS_9_QC',
#   'SWC_F_MDS_1_QC',
#   'SWC_F_MDS_2_QC',
#   'SWC_F_MDS_3_QC',
#   'SWC_F_MDS_5_QC',
#   'G_F_MDS_QC',
#   'LE_F_MDS_QC',
#   'H_F_MDS_QC',
#   'NEE_CUT_REF_QC',
#   'NEE_VUT_REF_QC',
#   'NEE_CUT_USTAR50_QC',
#   'NEE_VUT_USTAR50_QC',
#   'NEE_CUT_MEAN_QC',
#   'NEE_VUT_MEAN_QC',

# %%
_sel_param = ['day','TA_F','SW_IN_F','VPD_F','RH','WS_F','P_F',
             'GPP_NT_VUT_REF', 'GPP_DT_VUT_REF', 'RECO_NT_VUT_REF','RECO_DT_VUT_REF','NEE_VUT_REF'
             ] #'TIMESTAMP_START','TIMESTAMP_END','P',

# %%
_qc_param = ['TA_F_QC','SW_IN_F_QC','VPD_F_QC','PA_F_QC','P_F_QC','WS_F_QC','NEE_VUT_REF_QC']

# %% [raw]
# _sel_pd = data[_sel_param + _qc_param]
# _sel_pd

# %% [markdown]
# #### proce 'GPP_NT_VUT_REF', 'GPP_DT_VUT_REF', 'RECO_NT_VUT_REF','RECO_DT_VUT_REF','NEE_VUT_REF' daily average

# %%
day_of_year = pd.DataFrame()
#day_of_year['day'] = _sel_pd['day'].unique()

# %%
_sel_pd = data[['day','GPP_NT_VUT_REF', 'GPP_DT_VUT_REF', 'RECO_NT_VUT_REF','RECO_DT_VUT_REF','NEE_VUT_REF']]
_sel_pd_mean = _sel_pd.groupby(by = ['day']).mean().reset_index()

# %%
_sel_pd_mean

# %% [raw]
# # Keep the NT and DT columns seperately
# day_of_year['GPP_VUT_REF'] = _sel_pd_mean['GPP_NT_VUT_REF'] + _sel_pd_mean['GPP_DT_VUT_REF']
# day_of_year['RECO_VUT_REF'] = _sel_pd_mean['RECO_NT_VUT_REF'] + _sel_pd_mean['RECO_DT_VUT_REF']
# day_of_year['NEE_VUT_REF'] = _sel_pd_mean['NEE_VUT_REF']

# %%
day_of_year = _sel_pd_mean.copy()
day_of_year

# %% [raw]
# # 'day','TA_F','SW_IN_F','VPD_F','RH','WS_F','P','P_F',

# %% [markdown]
# #### process TA_F daily max and min value from half hour data

# %%
_sel_pd = data[['day','TA_F']]
_sel_taf_xx = _sel_pd.groupby(['day']).agg({'TA_F':['max','min']}).reset_index()
#_sel_pd_max = _sel_pd.groupby(by = ['day']).max().reset_index()
#_sel_pd_xx = _sel_pd.groupby(['day']).agg({'TA_F': ['mean', 'min', 'max'],'SW_IN_F': ['mean', 'min', 'max']}).reset_index()

# %%
_sel_taf_xx.columns

# %%
_sel_taf_xx[[('TA_F', 'max')]]

# %%
day_of_year['TA_F_max'] = _sel_taf_xx[('TA_F', 'max')].copy()
day_of_year['TA_F_min'] = _sel_taf_xx[('TA_F', 'min')].copy()

# %%
day_of_year

# %% [markdown]
# #### Process Humidity from RH, VPD_F and TA_F, then get per day's max and min humidity value

# %%
def VPD2RH(Ta,VPD):
    #
    #ea = 0.611*np.exp(17.502*Td/(Td+240.97))
    es = 0.611*np.exp(17.502*Ta/(Ta+240.97))*10
    ea = es-VPD
    RH = ea*100/es
    RH[RH<0] = 0
    RH[RH>100] = 100    
    return RH

def ConvertRH2Humidty(Ta,RH,ALTI):
    #Ta, air temperature, C
    #Rh, relatively humidty, %
    #ALTI,altitude,m
    DWPTH=0.61*np.exp(5360.0*(3.661E-03-1.0/(273.15+Ta)))*max(0.0,min(100.0,RH))*0.01 #humidity
    TKA=Ta+273.15
    VPS=0.61*np.exp(5360.0*(3.661E-03-1.0/TKA))*np.exp(-ALTI/7272.0)
    VPK=min(DWPTH,VPS)
    return VPK

# %%
data['VPD_F'].min()

# %%
RH2= VPD2RH(data['TA_F'].values, data['VPD_F'].values)

# %%
data['RH2'] = RH2

# %%
data[['RH2']]

# %%
RH2.mean(), RH2.max(),RH2.min()

# %%
# calculate humidity
ALTI = 362  # This is a fixed value
def calculate_H(row):
    if row['RH'] < 0:
        humidity = ConvertRH2Humidty(row['TA_F'],row['RH2'],ALTI)
    else:
        humidity = ConvertRH2Humidty(row['TA_F'],row['RH'],ALTI)

    return humidity


data['Humidity'] = data.apply (lambda row: calculate_H(row) , axis=1)

# %%
data[['Humidity']]

# %%
_sel_pd = data[['day','Humidity']]
_sel_H_xx = _sel_pd.groupby(['day']).agg({'Humidity':['max','min']}).reset_index()

# %%
day_of_year['H_max'] = _sel_H_xx[('Humidity', 'max')].copy()
day_of_year['H_min'] = _sel_H_xx[('Humidity', 'min')].copy()

# %%
day_of_year

# %% [markdown]
# ### Process SW_IN_F

# %%
# RAND: SW_IN_F, J: hour,I:DOY
def ConvertSWDW(RADN,ALAT,ZNOON,J,I):
    #
    #
    TWILGT=0.06976
    #
    RADN = RADN*0.0036
    TYSIN = 0
    for N in range(1,5):
        YAZI=3.1416*(2*N-1)/4.0
        YAGL=3.1416/4.0
        YSIN=np.sin(YAGL)
        TYSIN=TYSIN+YSIN

    # Note below code are duplicate for DECDAY and below lines
    if ALAT > 0.0:
        XI=173
    else:
        XI=356
    DECDAY=XI+100
    DECLIN=np.sin((DECDAY*0.9863)*1.7453E-02)*(-23.47)
    AZI=np.sin(ALAT*1.7453E-02)*np.sin(DECLIN*1.7453E-02)
    DEC=np.cos(ALAT*1.7453E-02)*np.cos(DECLIN*1.7453E-02)
    
    XI=I
    if I==366:
        XI=365.5
    DECDAY=XI+100
    DECLIN=np.sin((DECDAY*0.9863)*1.7453E-02)*(-23.47)
    AZI=np.sin(ALAT*1.7453E-02)*np.sin(DECLIN*1.7453E-02)
    DEC=np.cos(ALAT*1.7453E-02)*np.cos(DECLIN*1.7453E-02)    
    
    #
    SSIN=max(0.0,AZI+DEC*np.cos(0.2618*(ZNOON-(J-0.5))))
    #
    if RADN <=0:
        SSIN = 0
    if SSIN <= TWILGT*-1:
        RADN = 0
        
    if SSIN > 0:
        RADX=4.896*max(0.0,SSIN)    
        RADN = min(RADX,RADN)
        #DIRECT VS DIFFUSE RADIATION IN SOLAR OR SKY BEAMS
        RADZ=min(RADN,0.5*(RADX-RADN))
        RADS=(RADN-RADZ)/SSIN
        RADS=min(4.167,RADS)    
        RADY=RADZ/TYSIN        
        
        TRAD = RADS*SSIN+RADY*TYSIN
    else:
        TRAD = 0
    
    return TRAD

# %%
#RADN_hourly[year-start_year,DOY-1,hour-1] = ConvertSWDW(tmp_data['SW_IN_F'][i],ALAT,ZNOON,hour,DOY)

# %%
pd_site_param =pd.read_csv('site_info.csv')
pd_site_param

# %%
pd_site_param[pd_site_param['site_id'] == 'US-Wi0']['LOCATION_LAT'].values[0]

# %%
ALAT = pd_site_param[pd_site_param['site_id'] == 'US-Wi0']['LOCATION_LAT'].values[0] #46.618778 # site_data.Latitude.values[sitei]
ZNOON = 12.5

# %%
def calculate_RAND_HH(row):
    SW_IN_F = row['SW_IN_F']
    
    start_time = row['TIMESTAMP_START']
    year = int(start_time[:4])
    month = int(start_time[4:6])
    day_of_month = int(start_time[6:8])
    hour = int(start_time[8:10]) + 1   # hour is from 1 - 24
    day_of_year = datetime.datetime(int(year), int(month), int(day_of_month)).timetuple().tm_yday
    return ConvertSWDW(SW_IN_F,ALAT,ZNOON,hour,day_of_year)

# %%
data['RAND_HH'] = data.apply (lambda row: calculate_RAND_HH(row) , axis=1)

# %%
data['RAND_HH'].describe()

# %%
# RADN = np.sum(RADN_hourly,axis=-1)

_sel_pd = data[['day','RAND_HH']]
_sel_H_xx = _sel_pd.groupby(['day']).agg({'RAND_HH':'sum'}).reset_index()

# %%
day_of_year['RAND'] = _sel_H_xx['RAND_HH']

# %% [markdown]
# ### Process wind speed

# %%
def ConvertWindSpeed(row):
    #WS, wind speed, m/s
    WS = row['WS_F']
    WINDH=WS*3600.0 #m/h
    UA = max(3600,WINDH)*0.001 #km/h
    return UA

# %%
data['WIND_HH'] = data.apply (lambda row: ConvertWindSpeed(row) , axis=1)

# %%
_sel_pd = data[['day','WIND_HH']]
_sel_H_xx = _sel_pd.groupby(['day']).agg({'WIND_HH':'sum'}).reset_index()
day_of_year['WIND'] = _sel_H_xx['WIND_HH']

# %% [markdown]
# ### Process PRECN

# %%
_sel_pd = data[['day','P_F']]
_sel_H_xx = _sel_pd.groupby(['day']).agg({'P_F':'sum'}).reset_index()
day_of_year['PRECN'] = _sel_H_xx['P_F']

# %%
day_of_year

# %%
day_of_year.to_csv('processed_day_values.csv', float_format='%.5f', index=False)

# %% [markdown]
# ## QC data

# %%
US_Wi0_day_file = _dir + 'FLX_US-Wi0_FLUXNET2015_FULLSET_2002-2002_1-4/FLX_US-Wi0_FLUXNET2015_FULLSET_DD_2002-2002_1-4.csv'

day_data = pd.read_csv(US_Wi0_day_file, dtype={'TIMESTAMP':str})

# %%
day_data

# %%
_qc_param = ['TIMESTAMP','TA_F_QC','SW_IN_F_QC','VPD_F_QC','PA_F_QC','P_F_QC','WS_F_QC','NEE_VUT_REF_QC']
QC = day_data[_qc_param]
QC

# %%
QC.to_csv('DAY_QC_values.csv', float_format='%.5f', index=False)

# %% [markdown]
# # Process all sites fullnet data

# %%
_root = 'D:/Flux_net/'
all_zip = glob.glob(_root + "*FLUXNET2015_FULLSET*.zip")
len(all_zip)
# Out:
# 206

# %%
all_zip
# Out:
# ['D:/Flux_net\\FLX_AR-SLu_FLUXNET2015_FULLSET_2009-2011_1-4.zip',
#  'D:/Flux_net\\FLX_AR-Vir_FLUXNET2015_FULLSET_2009-2012_1-4.zip',
#  'D:/Flux_net\\FLX_AT-Neu_FLUXNET2015_FULLSET_2002-2012_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Ade_FLUXNET2015_FULLSET_2007-2009_1-4.zip',
#  'D:/Flux_net\\FLX_AU-ASM_FLUXNET2015_FULLSET_2010-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Cpr_FLUXNET2015_FULLSET_2010-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Cum_FLUXNET2015_FULLSET_2012-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-DaP_FLUXNET2015_FULLSET_2007-2013_2-4.zip',
#  'D:/Flux_net\\FLX_AU-DaS_FLUXNET2015_FULLSET_2008-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Dry_FLUXNET2015_FULLSET_2008-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Emr_FLUXNET2015_FULLSET_2011-2013_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Fog_FLUXNET2015_FULLSET_2006-2008_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Gin_FLUXNET2015_FULLSET_2011-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-GWW_FLUXNET2015_FULLSET_2013-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-How_FLUXNET2015_FULLSET_2001-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Lox_FLUXNET2015_FULLSET_2008-2009_1-4.zip',
#  'D:/Flux_net\\FLX_AU-RDF_FLUXNET2015_FULLSET_2011-2013_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Rig_FLUXNET2015_FULLSET_2011-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Rob_FLUXNET2015_FULLSET_2014-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Stp_FLUXNET2015_FULLSET_2008-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-TTE_FLUXNET2015_FULLSET_2012-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Tum_FLUXNET2015_FULLSET_2001-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Wac_FLUXNET2015_FULLSET_2005-2008_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Whr_FLUXNET2015_FULLSET_2011-2014_2-4.zip',
#  'D:/Flux_net\\FLX_AU-Wom_FLUXNET2015_FULLSET_2010-2014_1-4.zip',
#  'D:/Flux_net\\FLX_AU-Ync_FLUXNET2015_FULLSET_2012-2014_1-4.zip',
#  'D:/Flux_net\\FLX_BE-Bra_FLUXNET2015_FULLSET_1996-2014_2-4.zip',
#  'D:/Flux_net\\FLX_BE-Lon_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_BE-Vie_FLUXNET2015_FULLSET_1996-2014_1-4.zip',
#  'D:/Flux_net\\FLX_BR-Sa1_FLUXNET2015_FULLSET_2002-2011_1-4.zip',
#  'D:/Flux_net\\FLX_BR-Sa3_FLUXNET2015_FULLSET_2000-2004_1-4.zip',
#  'D:/Flux_net\\FLX_CA-Gro_FLUXNET2015_FULLSET_2003-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CA-Man_FLUXNET2015_FULLSET_1994-2008_1-4.zip',
#  'D:/Flux_net\\FLX_CA-NS1_FLUXNET2015_FULLSET_2001-2005_2-4.zip',
#  'D:/Flux_net\\FLX_CA-NS2_FLUXNET2015_FULLSET_2001-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-NS3_FLUXNET2015_FULLSET_2001-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-NS4_FLUXNET2015_FULLSET_2002-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-NS5_FLUXNET2015_FULLSET_2001-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-NS6_FLUXNET2015_FULLSET_2001-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-NS7_FLUXNET2015_FULLSET_2002-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-Oas_FLUXNET2015_FULLSET_1996-2010_1-4.zip',
#  'D:/Flux_net\\FLX_CA-Obs_FLUXNET2015_FULLSET_1997-2010_1-4.zip',
#  'D:/Flux_net\\FLX_CA-Qfo_FLUXNET2015_FULLSET_2003-2010_1-4.zip',
#  'D:/Flux_net\\FLX_CA-SF1_FLUXNET2015_FULLSET_2003-2006_1-4.zip',
#  'D:/Flux_net\\FLX_CA-SF2_FLUXNET2015_FULLSET_2001-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CA-SF3_FLUXNET2015_FULLSET_2001-2006_1-4.zip',
#  'D:/Flux_net\\FLX_CA-TP1_FLUXNET2015_FULLSET_2002-2014_2-4.zip',
#  'D:/Flux_net\\FLX_CA-TP2_FLUXNET2015_FULLSET_2002-2007_1-4.zip',
#  'D:/Flux_net\\FLX_CA-TP3_FLUXNET2015_FULLSET_2002-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CA-TP4_FLUXNET2015_FULLSET_2002-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CA-TPD_FLUXNET2015_FULLSET_2012-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CG-Tch_FLUXNET2015_FULLSET_2006-2009_1-4.zip',
#  'D:/Flux_net\\FLX_CH-Cha_FLUXNET2015_FULLSET_2005-2014_2-4.zip',
#  'D:/Flux_net\\FLX_CH-Dav_FLUXNET2015_FULLSET_1997-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CH-Fru_FLUXNET2015_FULLSET_2005-2014_2-4.zip',
#  'D:/Flux_net\\FLX_CH-Lae_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CH-Oe1_FLUXNET2015_FULLSET_2002-2008_2-4.zip',
#  'D:/Flux_net\\FLX_CH-Oe2_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Cha_FLUXNET2015_FULLSET_2003-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Cng_FLUXNET2015_FULLSET_2007-2010_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Dan_FLUXNET2015_FULLSET_2004-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Din_FLUXNET2015_FULLSET_2003-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Du2_FLUXNET2015_FULLSET_2006-2008_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Du3_FLUXNET2015_FULLSET_2009-2010_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Ha2_FLUXNET2015_FULLSET_2003-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CN-HaM_FLUXNET2015_FULLSET_2002-2004_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Qia_FLUXNET2015_FULLSET_2003-2005_1-4.zip',
#  'D:/Flux_net\\FLX_CN-Sw2_FLUXNET2015_FULLSET_2010-2012_1-4.zip',
#  'D:/Flux_net\\FLX_CZ-BK1_FLUXNET2015_FULLSET_2004-2014_2-4.zip',
#  'D:/Flux_net\\FLX_CZ-BK2_FLUXNET2015_FULLSET_2004-2012_2-4.zip',
#  'D:/Flux_net\\FLX_CZ-wet_FLUXNET2015_FULLSET_2006-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Akm_FLUXNET2015_FULLSET_2009-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Geb_FLUXNET2015_FULLSET_2001-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Gri_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Hai_FLUXNET2015_FULLSET_2000-2012_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Kli_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Lkb_FLUXNET2015_FULLSET_2009-2013_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Lnf_FLUXNET2015_FULLSET_2002-2012_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Obe_FLUXNET2015_FULLSET_2008-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-RuR_FLUXNET2015_FULLSET_2011-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-RuS_FLUXNET2015_FULLSET_2011-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Seh_FLUXNET2015_FULLSET_2007-2010_1-4.zip',
#  'D:/Flux_net\\FLX_DE-SfN_FLUXNET2015_FULLSET_2012-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Spw_FLUXNET2015_FULLSET_2010-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Tha_FLUXNET2015_FULLSET_1996-2014_1-4.zip',
#  'D:/Flux_net\\FLX_DE-Zrk_FLUXNET2015_FULLSET_2013-2014_2-4.zip',
#  'D:/Flux_net\\FLX_DK-Eng_FLUXNET2015_FULLSET_2005-2008_1-4.zip',
#  'D:/Flux_net\\FLX_DK-Fou_FLUXNET2015_FULLSET_2005-2005_1-4.zip',
#  'D:/Flux_net\\FLX_DK-Sor_FLUXNET2015_FULLSET_1996-2014_2-4.zip',
#  'D:/Flux_net\\FLX_ES-Amo_FLUXNET2015_FULLSET_2007-2012_1-4.zip',
#  'D:/Flux_net\\FLX_ES-LgS_FLUXNET2015_FULLSET_2007-2009_1-4.zip',
#  'D:/Flux_net\\FLX_ES-LJu_FLUXNET2015_FULLSET_2004-2013_1-4.zip',
#  'D:/Flux_net\\FLX_ES-Ln2_FLUXNET2015_FULLSET_2009-2009_1-4.zip',
#  'D:/Flux_net\\FLX_FI-Hyy_FLUXNET2015_FULLSET_1996-2014_1-4.zip',
#  'D:/Flux_net\\FLX_FI-Jok_FLUXNET2015_FULLSET_2000-2003_1-4.zip',
#  'D:/Flux_net\\FLX_FI-Let_FLUXNET2015_FULLSET_2009-2012_1-4.zip',
#  'D:/Flux_net\\FLX_FI-Lom_FLUXNET2015_FULLSET_2007-2009_1-4.zip',
#  'D:/Flux_net\\FLX_FI-Sod_FLUXNET2015_FULLSET_2001-2014_1-4.zip',
#  'D:/Flux_net\\FLX_FR-Fon_FLUXNET2015_FULLSET_2005-2014_1-4.zip',
#  'D:/Flux_net\\FLX_FR-Gri_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_FR-LBr_FLUXNET2015_FULLSET_1996-2008_1-4.zip',
#  'D:/Flux_net\\FLX_FR-Pue_FLUXNET2015_FULLSET_2000-2014_2-4.zip',
#  'D:/Flux_net\\FLX_GF-Guy_FLUXNET2015_FULLSET_2004-2014_2-4.zip',
#  'D:/Flux_net\\FLX_GH-Ank_FLUXNET2015_FULLSET_2011-2014_1-4.zip',
#  'D:/Flux_net\\FLX_GL-NuF_FLUXNET2015_FULLSET_2008-2014_1-4.zip',
#  'D:/Flux_net\\FLX_GL-ZaF_FLUXNET2015_FULLSET_2008-2011_2-4.zip',
#  'D:/Flux_net\\FLX_GL-ZaH_FLUXNET2015_FULLSET_2000-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-BCi_FLUXNET2015_FULLSET_2004-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-CA1_FLUXNET2015_FULLSET_2011-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-CA2_FLUXNET2015_FULLSET_2011-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-CA3_FLUXNET2015_FULLSET_2011-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-Col_FLUXNET2015_FULLSET_1996-2014_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Cp2_FLUXNET2015_FULLSET_2012-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-Cpz_FLUXNET2015_FULLSET_1997-2009_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Isp_FLUXNET2015_FULLSET_2013-2014_1-4.zip',
#  'D:/Flux_net\\FLX_IT-La2_FLUXNET2015_FULLSET_2000-2002_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Lav_FLUXNET2015_FULLSET_2003-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-MBo_FLUXNET2015_FULLSET_2003-2013_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Noe_FLUXNET2015_FULLSET_2004-2014_2-4.zip',
#  'D:/Flux_net\\FLX_IT-PT1_FLUXNET2015_FULLSET_2002-2004_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Ren_FLUXNET2015_FULLSET_1998-2013_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Ro1_FLUXNET2015_FULLSET_2000-2008_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Ro2_FLUXNET2015_FULLSET_2002-2012_1-4.zip',
#  'D:/Flux_net\\FLX_IT-SR2_FLUXNET2015_FULLSET_2013-2014_1-4.zip',
#  'D:/Flux_net\\FLX_IT-SRo_FLUXNET2015_FULLSET_1999-2012_1-4.zip',
#  'D:/Flux_net\\FLX_IT-Tor_FLUXNET2015_FULLSET_2008-2014_2-4.zip',
#  'D:/Flux_net\\FLX_JP-MBF_FLUXNET2015_FULLSET_2003-2005_1-4.zip',
#  'D:/Flux_net\\FLX_JP-SMF_FLUXNET2015_FULLSET_2002-2006_1-4.zip',
#  'D:/Flux_net\\FLX_MY-PSO_FLUXNET2015_FULLSET_2003-2009_1-4.zip',
#  'D:/Flux_net\\FLX_NL-Hor_FLUXNET2015_FULLSET_2004-2011_1-4.zip',
#  'D:/Flux_net\\FLX_NL-Loo_FLUXNET2015_FULLSET_1996-2014_1-4.zip',
#  'D:/Flux_net\\FLX_PA-SPn_FLUXNET2015_FULLSET_2007-2009_1-4.zip',
#  'D:/Flux_net\\FLX_PA-SPs_FLUXNET2015_FULLSET_2007-2009_1-4.zip',
#  'D:/Flux_net\\FLX_RU-Che_FLUXNET2015_FULLSET_2002-2005_1-4.zip',
#  'D:/Flux_net\\FLX_RU-Cok_FLUXNET2015_FULLSET_2003-2014_2-4.zip',
#  'D:/Flux_net\\FLX_RU-Fyo_FLUXNET2015_FULLSET_1998-2014_2-4.zip',
#  'D:/Flux_net\\FLX_RU-Ha1_FLUXNET2015_FULLSET_2002-2004_1-4.zip',
#  'D:/Flux_net\\FLX_SD-Dem_FLUXNET2015_FULLSET_2005-2009_2-4.zip',
#  'D:/Flux_net\\FLX_SJ-Adv_FLUXNET2015_FULLSET_2011-2014_1-4.zip',
#  'D:/Flux_net\\FLX_SJ-Blv_FLUXNET2015_FULLSET_2008-2009_1-4.zip',
#  'D:/Flux_net\\FLX_SN-Dhr_FLUXNET2015_FULLSET_2010-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-AR1_FLUXNET2015_FULLSET_2009-2012_1-4.zip',
#  'D:/Flux_net\\FLX_US-AR2_FLUXNET2015_FULLSET_2009-2012_1-4.zip',
#  'D:/Flux_net\\FLX_US-ARb_FLUXNET2015_FULLSET_2005-2006_1-4.zip',
#  'D:/Flux_net\\FLX_US-ARc_FLUXNET2015_FULLSET_2005-2006_1-4.zip',
#  'D:/Flux_net\\FLX_US-ARM_FLUXNET2015_FULLSET_2003-2012_1-4.zip',
#  'D:/Flux_net\\FLX_US-Atq_FLUXNET2015_FULLSET_2003-2008_1-4.zip',
#  'D:/Flux_net\\FLX_US-Blo_FLUXNET2015_FULLSET_1997-2007_1-4.zip',
#  'D:/Flux_net\\FLX_US-Cop_FLUXNET2015_FULLSET_2001-2007_1-4.zip',
#  'D:/Flux_net\\FLX_US-CRT_FLUXNET2015_FULLSET_2011-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-GBT_FLUXNET2015_FULLSET_1999-2006_1-4.zip',
#  'D:/Flux_net\\FLX_US-GLE_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Goo_FLUXNET2015_FULLSET_2002-2006_1-4.zip',
#  'D:/Flux_net\\FLX_US-Ha1_FLUXNET2015_FULLSET_1991-2012_1-4.zip',
#  'D:/Flux_net\\FLX_US-IB2_FLUXNET2015_FULLSET_2004-2011_1-4.zip',
#  'D:/Flux_net\\FLX_US-Ivo_FLUXNET2015_FULLSET_2004-2007_1-4.zip',
#  'D:/Flux_net\\FLX_US-KS1_FLUXNET2015_FULLSET_2002-2002_1-4.zip',
#  'D:/Flux_net\\FLX_US-KS2_FLUXNET2015_FULLSET_2003-2006_1-4.zip',
#  'D:/Flux_net\\FLX_US-Lin_FLUXNET2015_FULLSET_2009-2010_1-4.zip',
#  'D:/Flux_net\\FLX_US-Los_FLUXNET2015_FULLSET_2000-2014_2-4.zip',
#  'D:/Flux_net\\FLX_US-LWW_FLUXNET2015_FULLSET_1997-1998_1-4.zip',
#  'D:/Flux_net\\FLX_US-Me1_FLUXNET2015_FULLSET_2004-2005_1-4.zip',
#  'D:/Flux_net\\FLX_US-Me2_FLUXNET2015_FULLSET_2002-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Me3_FLUXNET2015_FULLSET_2004-2009_1-4.zip',
#  'D:/Flux_net\\FLX_US-Me4_FLUXNET2015_FULLSET_1996-2000_1-4.zip',
#  'D:/Flux_net\\FLX_US-Me5_FLUXNET2015_FULLSET_2000-2002_1-4.zip',
#  'D:/Flux_net\\FLX_US-Me6_FLUXNET2015_FULLSET_2010-2014_2-4.zip',
#  'D:/Flux_net\\FLX_US-MMS_FLUXNET2015_FULLSET_1999-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Myb_FLUXNET2015_FULLSET_2010-2014_2-4.zip',
#  'D:/Flux_net\\FLX_US-Ne1_FLUXNET2015_FULLSET_2001-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-Ne2_FLUXNET2015_FULLSET_2001-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-Ne3_FLUXNET2015_FULLSET_2001-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-NR1_FLUXNET2015_FULLSET_1998-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Oho_FLUXNET2015_FULLSET_2004-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-ORv_FLUXNET2015_FULLSET_2011-2011_1-4.zip',
#  'D:/Flux_net\\FLX_US-PFa_FLUXNET2015_FULLSET_1995-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Prr_FLUXNET2015_FULLSET_2010-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-SRC_FLUXNET2015_FULLSET_2008-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-SRG_FLUXNET2015_FULLSET_2008-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-SRM_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Sta_FLUXNET2015_FULLSET_2005-2009_1-4.zip',
#  'D:/Flux_net\\FLX_US-Syv_FLUXNET2015_FULLSET_2001-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Ton_FLUXNET2015_FULLSET_2001-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Tw1_FLUXNET2015_FULLSET_2012-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Tw2_FLUXNET2015_FULLSET_2012-2013_1-4.zip',
#  'D:/Flux_net\\FLX_US-Tw3_FLUXNET2015_FULLSET_2013-2014_2-4.zip',
#  'D:/Flux_net\\FLX_US-Tw4_FLUXNET2015_FULLSET_2013-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Twt_FLUXNET2015_FULLSET_2009-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-UMB_FLUXNET2015_FULLSET_2000-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-UMd_FLUXNET2015_FULLSET_2007-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Var_FLUXNET2015_FULLSET_2000-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-WCr_FLUXNET2015_FULLSET_1999-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Whs_FLUXNET2015_FULLSET_2007-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi0_FLUXNET2015_FULLSET_2002-2002_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi1_FLUXNET2015_FULLSET_2003-2003_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi2_FLUXNET2015_FULLSET_2003-2003_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi3_FLUXNET2015_FULLSET_2002-2004_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi4_FLUXNET2015_FULLSET_2002-2005_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi5_FLUXNET2015_FULLSET_2004-2004_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi6_FLUXNET2015_FULLSET_2002-2003_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi7_FLUXNET2015_FULLSET_2005-2005_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi8_FLUXNET2015_FULLSET_2002-2002_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wi9_FLUXNET2015_FULLSET_2004-2005_1-4.zip',
#  'D:/Flux_net\\FLX_US-Wkg_FLUXNET2015_FULLSET_2004-2014_1-4.zip',
#  'D:/Flux_net\\FLX_US-WPT_FLUXNET2015_FULLSET_2011-2013_1-4.zip',
#  'D:/Flux_net\\FLX_ZM-Mon_FLUXNET2015_FULLSET_2000-2009_2-4.zip']

# %%
file_name = all_zip[6]

file_prefix = os.path.basename(file_name)[:-4]

# %%
file_prefix

# %%
file_prefix.split('_')

# %%
'FLX_AU-Cum_FLUXNET2015_FULLSET_HH_2012-2014_2-4.csv'

# %%
len('_2012-2014_2-4')

# %%
file_prefix[:-14], file_prefix[-14:]

# %%
hh_file = file_prefix[:-14]+ '_HH'+ file_prefix[-14:]
hh_file

# %%
_sel_param = ['TA_F','SW_IN_F','VPD_F','RH','WS_F','P_F',
             'GPP_NT_VUT_REF', 'GPP_DT_VUT_REF', 'RECO_NT_VUT_REF','RECO_DT_VUT_REF','NEE_VUT_REF'
             ]

# %%
# specifying the zip file name
for file_name in all_zip:
    
    # opening the zip file in READ mode
    with ZipFile(file_name, 'r') as zip:
        # printing all the contents of the zip file
        #zip.printdir()
        file_list = zip.namelist()
        
        file_prefix = os.path.basename(file_name)[:-4]
        
        hh_file = file_prefix[:-14]+ '_HH'+ file_prefix[-14:] + '.csv'
        hr_file = file_prefix[:-14]+ '_HR'+ file_prefix[-14:] + '.csv'
        dd_file = file_prefix[:-14]+ '_DD'+ file_prefix[-14:] + '.csv'
        
        #dd_data = zip.read(dd_file)
        
        #pd_data = pd.read_csv(zip.open(dd_file), dtype={'TIMESTAMP':str})
        hour_file = ''
        if hh_file in file_list :
            hour_file = hh_file
        elif hr_file in file_list :
            hour_file = hr_file

        if hour_file != '':
            data = pd.read_csv(zip.open(hour_file), dtype={'TIMESTAMP_START':str, 'TIMESTAMP_END':str})
            # check if necessary parameters exist in Hourly file
            for item in _sel_param :
                if item not in data.columns:
                    print(hour_file, item)
            #process_hour_file(data, site_id, pd_site_param, output_dir)


print('Done!')

# %%
pd_data

# %% [markdown]
# ### Get each site start year and end year for site info

# %%
flux_site = pd.read_csv('all_sites_param.csv')

# %%
flux_site.insert(2,'end year',0)
flux_site.insert(2,'start year',0)

# %%
flux_site
# Out:
#     site_id                        SITE_NAME  start year  end year     MAP  \
# 0    AR-SLu                         San Luis           0         0   400.0
# 1    AR-Vir                         Virasoro           0         0 -9999.0
# 2    AT-Neu                         Neustift           0         0   852.0
# 3    AU-ASM                    Alice Springs           0         0 -9999.0
# 4    AU-Ade                   Adelaide River           0         0 -9999.0
# ..      ...                              ...         ...       ...     ...
# 207  US-Wi8    Young hardwood clearcut (YHW)           0         0 -9999.0
# 208  US-Wi9            Young Jack pine (YJP)           0         0 -9999.0
# 209  US-Wkg  Walnut Gulch Kendall Grasslands           0         0   407.0
# 210  ZA-Kru                          Skukuza           0         0   547.0
# 211  ZM-Mon                            Mongu           0         0   945.0
#
#           COUNTRY IGBP  LOCATION_LAT  LOCATION_LONG  UTC_OFFSET  ... VPD_F  \
# 0       Argentina   MF    -33.464800     -66.459800        -3.0  ...   hPa
# 1       Argentina  ENF    -28.239500     -56.188600        -3.0  ...   hPa
# 2         Austria  GRA     47.116670      11.317500         1.0  ...   hPa
# 3       Australia  SAV    -22.283000     133.249000         9.5  ...   hPa
# 4       Australia  WSA    -13.076900     131.117800         9.5  ...   hPa
# ..            ...  ...           ...            ...         ...  ...   ...
# 207           USA  DBF     46.722333     -91.252417        -6.0  ...   hPa
# 208           USA  ENF     46.618778     -91.081444        -6.0  ...   hPa
# 209           USA  GRA     31.736500    -109.941900        -7.0  ...   hPa
# 210  South Africa  SAV    -25.019700      31.496900         2.0  ...   NaN
# 211        Zambia  DBF    -15.439100      23.252500         2.0  ...   hPa
#
#        P  P_F   WS_F   RH      NEE_VUT_REF  RECO_NT_VUT_REF   GPP_NT_VUT_REF  \
# 0     mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 1    NaN   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 2     mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 3     mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 4    NaN   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# ..   ...  ...    ...  ...              ...              ...              ...
# 207   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 208   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 209   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 210  NaN  NaN    NaN  NaN              NaN              NaN              NaN
# 211   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
#
#      RECO_DT_VUT_REF   GPP_DT_VUT_REF
# 0    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 1    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 2    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 3    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 4    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# ..               ...              ...
# 207  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 208  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 209  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 210              NaN              NaN
# 211  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
#
# [212 rows x 23 columns]

# %%
for file_name in all_zip:
    # opening the zip file in READ mode
    with ZipFile(file_name, 'r') as zip:
        # printing all the contents of the zip file
        #zip.printdir()
        file_list = zip.namelist()
        
        file_prefix = os.path.basename(file_name)[:-4]
        site_id = file_prefix.split('_')[1]
        
        yy_file = file_prefix[:-14]+ '_YY'+ file_prefix[-14:] + '.csv'
        if yy_file in file_list:
            pd_data = pd.read_csv(zip.open(yy_file), dtype={'TIMESTAMP':str})
            flux_site.loc[flux_site['site_id'] == site_id, 'start year'] = pd_data['TIMESTAMP'].values[0]
            flux_site.loc[flux_site['site_id'] == site_id, 'end year'] = pd_data['TIMESTAMP'].values[-1]

# %%
flux_site
# Out:
#     site_id                        SITE_NAME start year end year     MAP  \
# 0    AR-SLu                         San Luis       2009     2011   400.0
# 1    AR-Vir                         Virasoro       2009     2012 -9999.0
# 2    AT-Neu                         Neustift       2002     2012   852.0
# 3    AU-ASM                    Alice Springs       2010     2014 -9999.0
# 4    AU-Ade                   Adelaide River       2007     2009 -9999.0
# ..      ...                              ...        ...      ...     ...
# 207  US-Wi8    Young hardwood clearcut (YHW)       2002     2002 -9999.0
# 208  US-Wi9            Young Jack pine (YJP)       2004     2005 -9999.0
# 209  US-Wkg  Walnut Gulch Kendall Grasslands       2004     2014   407.0
# 210  ZA-Kru                          Skukuza          0        0   547.0
# 211  ZM-Mon                            Mongu       2000     2009   945.0
#
#           COUNTRY IGBP  LOCATION_LAT  LOCATION_LONG  UTC_OFFSET  ... VPD_F  \
# 0       Argentina   MF    -33.464800     -66.459800        -3.0  ...   hPa
# 1       Argentina  ENF    -28.239500     -56.188600        -3.0  ...   hPa
# 2         Austria  GRA     47.116670      11.317500         1.0  ...   hPa
# 3       Australia  SAV    -22.283000     133.249000         9.5  ...   hPa
# 4       Australia  WSA    -13.076900     131.117800         9.5  ...   hPa
# ..            ...  ...           ...            ...         ...  ...   ...
# 207           USA  DBF     46.722333     -91.252417        -6.0  ...   hPa
# 208           USA  ENF     46.618778     -91.081444        -6.0  ...   hPa
# 209           USA  GRA     31.736500    -109.941900        -7.0  ...   hPa
# 210  South Africa  SAV    -25.019700      31.496900         2.0  ...   NaN
# 211        Zambia  DBF    -15.439100      23.252500         2.0  ...   hPa
#
#        P  P_F   WS_F   RH      NEE_VUT_REF  RECO_NT_VUT_REF   GPP_NT_VUT_REF  \
# 0     mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 1    NaN   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 2     mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 3     mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 4    NaN   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# ..   ...  ...    ...  ...              ...              ...              ...
# 207   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 208   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 209   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 210  NaN  NaN    NaN  NaN              NaN              NaN              NaN
# 211   mm   mm  m s-1    %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
#
#      RECO_DT_VUT_REF   GPP_DT_VUT_REF
# 0    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 1    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 2    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 3    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 4    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# ..               ...              ...
# 207  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 208  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 209  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 210              NaN              NaN
# 211  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
#
# [212 rows x 23 columns]

# %% [raw]
# flux_site.to_csv('all_sites_param.csv',float_format='%.5f', index=False)

# %% [markdown]
# ## Process SRDB data

# %%
#dtype={'Study_midyear':float, 'YearsOfData':float,'Collar_height':float, 'RC_season':str}

# %%
srdb_data = pd.read_csv('srdb-data-V5.csv',dtype={'Study_midyear':float, 'YearsOfData':float,'Duplicate_record':str,
                                                  'Collar_height':str, 'RC_season':str})
srdb_data
# Out:
#        Record_number  Entry_date  Study_number         Author  \
# 0                1.0  2008-09-26          2534  Bond-Lamberty
# 1                2.0  2008-09-26          2534  Bond-Lamberty
# 2                3.0  2008-09-26          2534  Bond-Lamberty
# 3                4.0  2008-09-26          2534  Bond-Lamberty
# 4                5.0  2008-09-26          2534  Bond-Lamberty
# ...              ...         ...           ...            ...
# 10361        10425.0  2020-04-13         11965        Ivanov
# 10362        10426.0  2020-04-13         11965        Ivanov
# 10363        10427.0  2020-04-13         11966        Ivanov
# 10364        10428.0  2020-04-14         12000       Yuzbekov
# 10365        10429.0  2020-04-14         12000       Yuzbekov
#
#       Duplicate_record Quality_flag Contributor  Country     Region  \
# 0                  NaN          Q02         BBL   Canada   Manitoba
# 1                  NaN          Q02         BBL   Canada   Manitoba
# 2                  NaN          Q02         BBL   Canada   Manitoba
# 3                  NaN          Q02         BBL   Canada   Manitoba
# 4                  NaN          Q02         BBL   Canada   Manitoba
# ...                ...          ...         ...      ...        ...
# 10361              NaN          NaN          NK   Russia  Far East
# 10362              NaN          NaN          NK   Russia  Far East
# 10363              NaN          NaN          NK  Russia   Far East
# 10364              NaN          NaN          NK  Russia   Novgorod
# 10365              NaN          NaN          NK  Russia   Novgorod
#
#               Site_name  ...    BA  C_veg_total    C_AG   C_BG   C_CR   C_FR  \
# 0      BOREAS NSA-D1998  ...   0.0        200.0    80.0  120.0   70.0   50.0
# 1      BOREAS NSA-D1995  ...   0.5        160.0    90.0   70.0   40.0   30.0
# 2      BOREAS NSA-D1989  ...   0.0        520.0   400.0  120.0   70.0   50.0
# 3      BOREAS NSA-D1981  ...   4.1       1050.0   700.0  350.0  230.0  120.0
# 4      BOREAS NSA-D1964  ...  11.6       2300.0  1500.0  800.0  600.0  200.0
# ...                 ...  ...   ...          ...     ...    ...    ...    ...
# 10361        Primorskii  ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10362        Primorskii  ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10363               NaN  ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10364           Valday   ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10365           Valday   ...   NaN          NaN     NaN    NaN    NaN    NaN
#
#       C_litter C_soilmineral  C_soildepth  \
# 0          NaN       41800.0         70.0
# 1          NaN       41800.0         70.0
# 2          NaN       41800.0         70.0
# 3          NaN       41800.0         70.0
# 4          NaN       41800.0         70.0
# ...        ...           ...          ...
# 10361      NaN           NaN          NaN
# 10362      NaN           NaN          NaN
# 10363      NaN           NaN          NaN
# 10364      NaN           NaN          NaN
# 10365      NaN           NaN          NaN
#
#                                                    Notes
# 0      LAI from Bond-Lamberty (2002); C from Wang (20...
# 1      LAI from Bond-Lamberty (2002); C from Wang (20...
# 2      LAI from Bond-Lamberty (2002); C from Wang (20...
# 3      LAI from Bond-Lamberty (2002); C from Wang (20...
# 4      LAI from Bond-Lamberty (2002); C from Wang (20...
# ...                                                  ...
# 10361                                                NaN
# 10362                                                NaN
# 10363                                                NaN
# 10364                                                NaN
# 10365                                                NaN
#
# [10366 rows x 85 columns]

# %%
srdb_data.columns[[4,39,61]]
# Out:
# Index(['Duplicate_record', 'Collar_height', 'RC_season'], dtype='object')

# %% [raw]
# _location = srdb_data[['Record_number','Site_name','Study_midyear','YearsOfData','Latitude','Longitude','MAT','MAP','Rs_annual','Ra_annual','Rh_annual',
#                       'Rs_spring','Rs_summer','Rs_autumn','Rs_winter','Rs_growingseason',
#                       'GPP','ER','NEP','NPP','ANPP','BNPP']]
# _location

# %% [markdown]
# #### Create SRDB related start year and end year in a new Data Frame

# %%
srdb_years = srdb_data[['Record_number','Site_name','Site_ID','Latitude','Longitude','Study_midyear','YearsOfData']].copy()
srdb_years
# Out:
#        Record_number         Site_name        Site_ID  Latitude  Longitude  \
# 0                1.0  BOREAS NSA-D1998   CA-BND-3YRWD    56.630    -99.940
# 1                2.0  BOREAS NSA-D1995   CA-BND-6YRWD    56.460    -99.970
# 2                3.0  BOREAS NSA-D1989  CA-BND-12YRWD    55.910    -98.980
# 3                4.0  BOREAS NSA-D1981  CA-BND-20YRWD    55.860    -98.480
# 4                5.0  BOREAS NSA-D1964  CA-BND-37YRWD    55.920    -98.390
# ...              ...               ...            ...       ...        ...
# 10361        10425.0        Primorskii     RU-FE-PRIM    43.630    132.250
# 10362        10426.0        Primorskii     RU-FE-PRIM    43.630    132.250
# 10363        10427.0               NaN          RU-FE    46.630    132.260
# 10364        10428.0           Valday      RU-NOVG-MG    50.012     33.345
# 10365        10429.0           Valday      RU-NOVG-NT    50.012     33.345
#
#        Study_midyear  YearsOfData
# 0             2001.5          1.5
# 1             2001.5          1.5
# 2             2001.5          1.5
# 3             2001.5          1.5
# 4             2001.5          1.5
# ...              ...          ...
# 10361         2015.0          1.0
# 10362         2016.0          1.0
# 10363         2015.0          1.0
# 10364            NaN          1.0
# 10365            NaN          1.0
#
# [10366 rows x 7 columns]

# %%
def get_startyear(row):
    if pd.isnull(row['Study_midyear']) or pd.isnull(row['YearsOfData']):
        return ''
    tmp = row['Study_midyear'] - row['YearsOfData']*0.5
    remain,year = math.modf(tmp)
    return str(int(year))+'.'+str(int(remain*12))

# %%
srdb_years['start_year'] = srdb_data.apply(lambda row: get_startyear(row),axis=1)

# %% [raw]
# srdb_data.columns.get_loc('YearsOfData')

# %% [raw]
# srdb_data.insert(13,'end_year','')
# srdb_data.insert(13,'start_year','')
# srdb_data[['start_year','end_year']]

# %%
def get_endyear(row):
    if pd.isnull(row['Study_midyear']) or pd.isnull(row['YearsOfData']):
        return ''
    tmp = row['Study_midyear'] + row['YearsOfData']*0.5
    remain,year = math.modf(tmp)
    return str(int(year))+'.'+str(int(remain*12))

# %%
srdb_years['end_year'] = srdb_data.apply(lambda row: get_endyear(row),axis=1)

# %%
srdb_years
# Out:
#        Record_number         Site_name        Site_ID  Latitude  Longitude  \
# 0                1.0  BOREAS NSA-D1998   CA-BND-3YRWD    56.630    -99.940
# 1                2.0  BOREAS NSA-D1995   CA-BND-6YRWD    56.460    -99.970
# 2                3.0  BOREAS NSA-D1989  CA-BND-12YRWD    55.910    -98.980
# 3                4.0  BOREAS NSA-D1981  CA-BND-20YRWD    55.860    -98.480
# 4                5.0  BOREAS NSA-D1964  CA-BND-37YRWD    55.920    -98.390
# ...              ...               ...            ...       ...        ...
# 10361        10425.0        Primorskii     RU-FE-PRIM    43.630    132.250
# 10362        10426.0        Primorskii     RU-FE-PRIM    43.630    132.250
# 10363        10427.0               NaN          RU-FE    46.630    132.260
# 10364        10428.0           Valday      RU-NOVG-MG    50.012     33.345
# 10365        10429.0           Valday      RU-NOVG-NT    50.012     33.345
#
#        Study_midyear  YearsOfData start_year end_year
# 0             2001.5          1.5     2000.9   2002.3
# 1             2001.5          1.5     2000.9   2002.3
# 2             2001.5          1.5     2000.9   2002.3
# 3             2001.5          1.5     2000.9   2002.3
# 4             2001.5          1.5     2000.9   2002.3
# ...              ...          ...        ...      ...
# 10361         2015.0          1.0     2014.6   2015.6
# 10362         2016.0          1.0     2015.6   2016.6
# 10363         2015.0          1.0     2014.6   2015.6
# 10364            NaN          1.0
# 10365            NaN          1.0
#
# [10366 rows x 9 columns]

# %%
flux_site = pd.read_csv('all_sites_param.csv')
flux_site_loc = flux_site[['site_id','LOCATION_LAT','LOCATION_LONG']].copy()
flux_site_loc
# Out:
#     site_id  LOCATION_LAT  LOCATION_LONG
# 0    AR-SLu     -33.46480      -66.45980
# 1    AR-Vir     -28.23950      -56.18860
# 2    AT-Neu      47.11667       11.31750
# 3    AU-ASM     -22.28300      133.24900
# 4    AU-Ade     -13.07690      131.11780
# ..      ...           ...            ...
# 207  US-Wi8      46.72233      -91.25242
# 208  US-Wi9      46.61878      -91.08144
# 209  US-Wkg      31.73650     -109.94190
# 210  ZA-Kru     -25.01970       31.49690
# 211  ZM-Mon     -15.43910       23.25250
#
# [212 rows x 3 columns]

# %% [raw]
# for _idx, row in flux_site_loc.iterrows():
#
#     lat = row['LOCATION_LAT']
#     long = row['LOCATION_LONG']
#
#     flux_site_loc.at[_idx,'Lat_min'] = abs(_location['Latitude'] - lat).min()
#     flux_site_loc.at[_idx,'Long_min'] = abs(_location['Longitude'] - long).min()

# %% [raw]
# # code is for repeate flux site data with matched SRDB data. But we don't use those code
# gap = 0.001
# _pd = pd.DataFrame()
# for _idx, site_row in flux_site_loc.iterrows():
#     lat  = site_row['LOCATION_LAT']
#     #lat_min = site_row['Lat_min']
#     long = site_row['LOCATION_LONG']
#     #long_min = site_row['Long_min']
#     _match_lat = srdb_data[abs(srdb_data['Latitude'] - lat) <= gap]
#     if _match_lat.shape[0] > 0:
#         #for _idx, srdb_row in _match_lat.iterrows():
#         _match_long = _match_lat[abs(_match_lat['Longitude'] - long) <= gap]
#         if _match_long.shape[0] > 0:
#             #print(_match_long)
#             # repeat df1 rows to match the number of rows in df2
#             _df_site = site_row.to_frame().T
#             _df_site = pd.concat([_df_site]*len(_match_long), ignore_index=True).reindex(columns=_df_site.columns)
#
#             # combine dataframes
#             _match_long.reset_index(inplace=True)
#             if not _pd.empty:
#                 result = pd.concat([_df_site, _match_long], axis=1)
#                 _pd = pd.concat([_pd,result], ignore_index=True)#.reset_index()
#             else:
#                 _pd = pd.concat([_df_site, _match_long], axis=1)
#
#             file_name = site_row['site_id'] + '_SRDB.csv'
#             _pd.to_csv(file_name,float_format='%.5f', index=False)
#             break

# %%
_pd.to_csv()
# Out:
#   site_id LOCATION_LAT LOCATION_LONG  index  Record_number  Entry_date  \
# 0  AU-Tum     -35.6566      148.1517   3671         3707.0  2010-05-11
# 1  AU-Tum     -35.6566      148.1517   3672         3708.0  2010-05-11
# 2  AU-Tum     -35.6566      148.1517   3673         3709.0  2010-05-11
#
#    Study_number Author Duplicate_record Quality_flag  ...    BA C_veg_total  \
# 0          4920  Keith              NaN          NaN  ...  35.0         NaN
# 1          4920  Keith              NaN          NaN  ...  35.0         NaN
# 2          4920  Keith              NaN          NaN  ...  35.0         NaN
#
#   C_AG C_BG C_CR  C_FR  C_litter C_soilmineral C_soildepth  Notes
# 0  NaN  NaN  NaN   NaN       NaN           NaN         NaN    NaN
# 1  NaN  NaN  NaN   NaN       NaN           NaN         NaN    NaN
# 2  NaN  NaN  NaN   NaN       NaN           NaN         NaN    NaN
#
# [3 rows x 91 columns]

# %%
#Write to files, one site one file

_dir = './site_SRDB/group1/'
gap = 0.01

output_dir = _dir + 'gap_'+ str(gap) + '/'

# %%
output_dir
# Out:
# './site_SRDB/group1/gap_0.01/'

# %%
_match_long
# Out:
#       Record_number Site_name  Study_midyear  YearsOfData  Latitude  \
# 7845         7900.0       NaN         2010.5          1.0    -28.23
# 7846         7901.0       NaN         2011.5          1.0    -28.23
#
#       Longitude   MAT     MAP  Rs_annual  Ra_annual  ...  Rs_summer  \
# 7845     -56.19  21.1  1800.0        NaN        NaN  ...        NaN
# 7846     -56.19  21.1  1800.0        NaN        NaN  ...        NaN
#
#       Rs_autumn  Rs_winter  Rs_growingseason     GPP  ER  NEP  NPP  ANPP  BNPP
# 7845        NaN        NaN               NaN  4290.0 NaN  NaN  NaN   NaN   NaN
# 7846        NaN        NaN               NaN  4015.0 NaN  NaN  NaN   NaN   NaN
#
# [2 rows x 22 columns]

# %%
# Group 1, fluxnet sites can related to SRDB
group_1 = list()
srdb_group1 = list()
for _idx, site_row in flux_site_loc.iterrows():
    lat  = site_row['LOCATION_LAT']
    long = site_row['LOCATION_LONG']

    _match_lat = srdb_data[abs(srdb_data['Latitude'] - lat) <= gap]

    if _match_lat.shape[0] > 0:
        #for _idx, srdb_row in _match_lat.iterrows():
        _match_long = _match_lat[abs(_match_lat['Longitude'] - long) <= gap]

        if _match_long.shape[0] > 0:
            site_id = site_row['site_id']
            file_name = output_dir + site_id + '_SRDB.csv'
            srdb_years_name = output_dir + site_id + '_SRDB_years.csv'
            
            group_1.append(site_id)
            srdb_group1.extend(_match_long.index.tolist())
            
            row_years = srdb_years.iloc[_match_long.index]
            _match_long.to_csv(file_name, float_format='%.5f', index=False)
            print('output file: ', file_name)
            
            row_years.to_csv(srdb_years_name,float_format='%.5f', index=False)
            print('output file: ', srdb_years_name)
# Out:
# output file:  ./site_SRDB/group1/gap_0.01/AR-Vir_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/AR-Vir_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/AT-Neu_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/AT-Neu_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/AU-Tum_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/AU-Tum_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/AU-Wom_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/AU-Wom_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/BE-Bra_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/BE-Bra_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/BE-Lon_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/BE-Lon_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/BE-Vie_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/BE-Vie_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Gro_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Gro_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Man_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Man_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS3_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS3_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS4_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS4_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS5_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS5_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS7_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-NS7_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Oas_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Oas_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Obs_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Obs_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Qfo_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-Qfo_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-SF1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-SF1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-SF2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-SF2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP3_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP3_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP4_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CA-TP4_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CG-Tch_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CG-Tch_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Cha_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Cha_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Fru_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Fru_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Lae_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Lae_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Oe1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Oe1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Oe2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CH-Oe2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Cha_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Cha_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Dan_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Dan_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Din_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Din_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Ha2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Ha2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Qia_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Qia_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Sw2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CN-Sw2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CZ-BK1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CZ-BK1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CZ-BK2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CZ-BK2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/CZ-wet_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/CZ-wet_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-Geb_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-Geb_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-Hai_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-Hai_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-RuS_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-RuS_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-Seh_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/DE-Seh_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/DK-Sor_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/DK-Sor_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/ES-Amo_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/ES-Amo_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/FR-Fon_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/FR-Fon_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/FR-Pue_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/FR-Pue_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Col_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Col_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Cpz_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Cpz_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-La2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-La2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Lav_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Lav_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-MBo_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-MBo_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Noe_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Noe_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Ren_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Ren_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Ro2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-Ro2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-SR2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-SR2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-SRo_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/IT-SRo_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/MY-PSO_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/MY-PSO_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/PA-SPn_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/PA-SPn_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/PA-SPs_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/PA-SPs_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/RU-Vrk_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/RU-Vrk_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/SD-Dem_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/SD-Dem_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Blo_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Blo_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Ha1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Ha1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-MMS_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-MMS_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me2_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me2_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me3_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me3_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me4_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me4_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me5_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me5_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me6_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Me6_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-NR1_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-NR1_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Oho_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Oho_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-PFa_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-PFa_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Prr_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Prr_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-SRM_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-SRM_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Syv_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Syv_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Ton_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Ton_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-UMB_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-UMB_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Var_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/US-Var_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/ZA-Kru_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/ZA-Kru_SRDB_years.csv
# output file:  ./site_SRDB/group1/gap_0.01/ZM-Mon_SRDB.csv
# output file:  ./site_SRDB/group1/gap_0.01/ZM-Mon_SRDB_years.csv

# %%
row_years = srdb_years.iloc[_match_long.index]
row_years
# Out:
#       Record_number              Site_name       Site_ID  Latitude  Longitude  \
# 4373         4407.0  Kataba Forest Reserve  ZM-KFR-PLOT1    -15.43      23.25
# 4374         4408.0  Kataba Forest Reserve  ZM-KFR-PLOT2    -15.43      23.25
# 4375         4409.0  Kataba Forest Reserve  ZM-KFR-PLOT3    -15.43      23.25
# 4376         4410.0  Kataba Forest Reserve  ZM-KFR-PLOT1    -15.43      23.25
# 4377         4411.0  Kataba Forest Reserve  ZM-KFR-PLOT2    -15.43      23.25
# 4378         4412.0  Kataba Forest Reserve  ZM-KFR-PLOT3    -15.43      23.25
# 4379         4413.0  Kataba Forest Reserve  ZM-KFR-PLOT4    -15.43      23.25
#
#       Study_midyear  YearsOfData start_year end_year
# 4373         2008.0          1.0     2007.6   2008.6
# 4374         2008.0          1.0     2007.6   2008.6
# 4375         2008.0          1.0     2007.6   2008.6
# 4376         2009.0          1.0     2008.6   2009.6
# 4377         2009.0          1.0     2008.6   2009.6
# 4378         2009.0          1.0     2008.6   2009.6
# 4379         2009.0          1.0     2008.6   2009.6

# %%
_match_long
# Out:
#       Record_number  Entry_date  Study_number   Author Duplicate_record  \
# 4373         4407.0  2012-03-11          6151  Merbold              NaN
# 4374         4408.0  2012-03-11          6151  Merbold              NaN
# 4375         4409.0  2012-03-11          6151  Merbold              NaN
# 4376         4410.0  2012-03-11          6151  Merbold              NaN
# 4377         4411.0  2012-03-11          6151  Merbold              NaN
# 4378         4412.0  2012-03-11          6151  Merbold              NaN
# 4379         4413.0  2012-03-11          6151  Merbold              NaN
#
#      Quality_flag Contributor Country            Region  \
# 4373          NaN         BBL  Zambia  Western Province
# 4374          NaN         BBL  Zambia  Western Province
# 4375          NaN         BBL  Zambia  Western Province
# 4376          NaN         BBL  Zambia  Western Province
# 4377          NaN         BBL  Zambia  Western Province
# 4378          NaN         BBL  Zambia  Western Province
# 4379          NaN         BBL  Zambia  Western Province
#
#                   Site_name  ...  BA  C_veg_total  C_AG  C_BG  C_CR  C_FR  \
# 4373  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
# 4374  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
# 4375  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
# 4376  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
# 4377  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
# 4378  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
# 4379  Kataba Forest Reserve  ... NaN          NaN   NaN   NaN   NaN   NaN
#
#      C_litter C_soilmineral  C_soildepth  Notes
# 4373      NaN           NaN          NaN    NaN
# 4374      NaN           NaN          NaN    NaN
# 4375      NaN           NaN          NaN    NaN
# 4376      NaN           NaN          NaN    NaN
# 4377      NaN           NaN          NaN    NaN
# 4378      NaN           NaN          NaN    NaN
# 4379      NaN           NaN          NaN    NaN
#
# [7 rows x 85 columns]

# %% [raw]
# # Group 2, fluxnet sites can not related to SRDB
# group_1 = list()
# srdb_group1 = list()
# for _idx, site_row in flux_site_loc.iterrows():
#     lat  = site_row['LOCATION_LAT']
#     long = site_row['LOCATION_LONG']
#
#     _match_lat = _location[abs(_location['Latitude'] - lat) <= gap]
#
#     if _match_lat.shape[0] > 0:
#         #for _idx, srdb_row in _match_lat.iterrows():
#         _match_long = _match_lat[abs(_match_lat['Longitude'] - long) <= gap]
#
#         if _match_long.shape[0] > 0:
#             site_id = site_row['site_id']
#             group_1.append(site_id)
#             srdb_group1.extend(_match_long.index.tolist())

# %%
len(group_1)
# Out:
# 82

# %%
srdb_group1
# Out:
# [7845,
#  7846,
#  2311,
#  9479,
#  3671,
#  3672,
#  3673,
#  6012,
#  6013,
#  8713,
#  8714,
#  8715,
#  1041,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1945,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2062,
#  2322,
#  2323,
#  2324,
#  2325,
#  2326,
#  2327,
#  2328,
#  2329,
#  2330,
#  2331,
#  2332,
#  2333,
#  2662,
#  4425,
#  4519,
#  560,
#  561,
#  2057,
#  2064,
#  136,
#  137,
#  6,
#  13,
#  20,
#  27,
#  301,
#  302,
#  303,
#  1443,
#  1773,
#  6,
#  13,
#  20,
#  27,
#  301,
#  302,
#  303,
#  1443,
#  1773,
#  5,
#  19,
#  4,
#  11,
#  18,
#  25,
#  4,
#  11,
#  18,
#  25,
#  3,
#  10,
#  17,
#  24,
#  0,
#  7,
#  14,
#  21,
#  121,
#  164,
#  41,
#  42,
#  78,
#  79,
#  89,
#  122,
#  451,
#  2975,
#  3769,
#  4965,
#  1401,
#  1400,
#  5857,
#  5858,
#  4255,
#  5859,
#  5860,
#  4255,
#  5859,
#  5860,
#  4721,
#  4722,
#  7322,
#  8004,
#  8005,
#  5639,
#  3868,
#  3869,
#  3870,
#  3871,
#  3872,
#  3873,
#  3874,
#  3875,
#  3876,
#  3877,
#  3878,
#  3879,
#  3880,
#  3881,
#  3882,
#  3883,
#  3884,
#  3885,
#  3886,
#  3887,
#  3888,
#  3889,
#  3890,
#  3891,
#  3892,
#  3893,
#  3894,
#  3895,
#  3896,
#  3897,
#  3898,
#  3899,
#  3900,
#  3901,
#  3902,
#  3903,
#  4200,
#  4201,
#  4202,
#  4203,
#  4204,
#  4205,
#  4206,
#  4207,
#  4208,
#  4209,
#  2091,
#  2091,
#  470,
#  2844,
#  2961,
#  2962,
#  2978,
#  3011,
#  3012,
#  3056,
#  3057,
#  4075,
#  4076,
#  4077,
#  4125,
#  7627,
#  7628,
#  7629,
#  7630,
#  9476,
#  9477,
#  9478,
#  7155,
#  7156,
#  7157,
#  7158,
#  7159,
#  7160,
#  7421,
#  7422,
#  7423,
#  7424,
#  7425,
#  7426,
#  8729,
#  8730,
#  8731,
#  9550,
#  567,
#  568,
#  569,
#  2423,
#  2424,
#  2425,
#  2702,
#  2703,
#  2704,
#  2737,
#  2738,
#  2739,
#  5390,
#  5391,
#  5392,
#  5393,
#  5394,
#  5395,
#  5396,
#  5397,
#  5398,
#  7247,
#  7248,
#  3395,
#  3396,
#  3397,
#  4626,
#  4627,
#  4628,
#  4629,
#  4630,
#  4631,
#  5075,
#  5076,
#  5077,
#  5078,
#  8793,
#  8794,
#  8795,
#  8796,
#  8797,
#  9446,
#  8358,
#  8359,
#  8360,
#  8361,
#  8362,
#  8363,
#  8364,
#  8365,
#  9671,
#  9672,
#  9677,
#  9678,
#  9683,
#  9684,
#  10207,
#  10232,
#  10233,
#  10234,
#  10235,
#  10236,
#  10237,
#  3333,
#  5143,
#  6514,
#  6515,
#  9547,
#  9548,
#  9549,
#  10193,
#  3333,
#  5143,
#  6514,
#  6515,
#  8627,
#  1025,
#  48,
#  49,
#  1390,
#  1863,
#  1864,
#  1865,
#  4232,
#  4233,
#  4234,
#  4235,
#  4236,
#  4237,
#  4238,
#  4239,
#  6602,
#  6602,
#  631,
#  632,
#  816,
#  817,
#  5790,
#  4659,
#  4257,
#  4258,
#  4259,
#  3807,
#  3808,
#  3809,
#  3810,
#  5384,
#  8728,
#  1704,
#  2300,
#  1704,
#  2300,
#  1705,
#  3552,
#  6841,
#  6842,
#  9500,
#  9707,
#  9784,
#  9785,
#  10092,
#  2302,
#  139,
#  2845,
#  2846,
#  2847,
#  2848,
#  8727,
#  8727,
#  794,
#  1376,
#  1377,
#  1378,
#  8138,
#  8139,
#  1752,
#  1753,
#  1754,
#  4250,
#  4251,
#  4482,
#  4483,
#  4484,
#  4485,
#  4486,
#  4487,
#  1752,
#  1753,
#  1754,
#  4250,
#  4251,
#  8225,
#  8226,
#  8227,
#  8228,
#  7754,
#  7755,
#  7756,
#  565,
#  600,
#  839,
#  1053,
#  1054,
#  1055,
#  1681,
#  2305,
#  2306,
#  2307,
#  2308,
#  2309,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  192,
#  193,
#  194,
#  195,
#  196,
#  202,
#  203,
#  204,
#  205,
#  206,
#  212,
#  213,
#  214,
#  215,
#  216,
#  547,
#  548,
#  549,
#  550,
#  551,
#  552,
#  856,
#  1270,
#  1271,
#  1307,
#  1308,
#  1309,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  2059,
#  5288,
#  5289,
#  5290,
#  5291,
#  5292,
#  5293,
#  5294,
#  5295,
#  5296,
#  5297,
#  5298,
#  5299,
#  5300,
#  5301,
#  5302,
#  5303,
#  5304,
#  5305,
#  5306,
#  5307,
#  5308,
#  5309,
#  5310,
#  5311,
#  5312,
#  5313,
#  5314,
#  5315,
#  5316,
#  5317,
#  5318,
#  5319,
#  5320,
#  5321,
#  5322,
#  5323,
#  5324,
#  5325,
#  5326,
#  5327,
#  5328,
#  5329,
#  5330,
#  5331,
#  5332,
#  5333,
#  5334,
#  5335,
#  5336,
#  5337,
#  5338,
#  5339,
#  5340,
#  5341,
#  5342,
#  5343,
#  5344,
#  5345,
#  5346,
#  5347,
#  5348,
#  5349,
#  5350,
#  5351,
#  5352,
#  5353,
#  5354,
#  5355,
#  5356,
#  5357,
#  5358,
#  5359,
#  5360,
#  5361,
#  5362,
#  5363,
#  5364,
#  5365,
#  5366,
#  5367,
#  5368,
#  5369,
#  5370,
#  5371,
#  5372,
#  5373,
#  5374,
#  5375,
#  5376,
#  5377,
#  5852,
#  5853,
#  2850,
#  2851,
#  2852,
#  2853,
#  2854,
#  2855,
#  2856,
#  2857,
#  2858,
#  2859,
#  992,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  4986,
#  4987,
#  756,
#  757,
#  2051,
#  2116,
#  4986,
#  4987,
#  2652,
#  2653,
#  2654,
#  2735,
#  2736,
#  3207,
#  3726,
#  3414,
#  7057,
#  7058,
#  7059,
#  7060,
#  4434,
#  4435,
#  4436,
#  10003,
#  1402,
#  1403,
#  1404,
#  1405,
#  3422,
#  236,
#  566,
#  1014,
#  2070,
#  2060,
#  1015,
#  6014,
#  6015,
#  6080,
#  6081,
#  4373,
#  4374,
#  4375,
#  4376,
#  4377,
#  4378,
#  4379]

# %% [raw]
# full_site = flux_site['site_id'].values.tolist()
# group_2 = [item for item in full_site if item not in group_1]
# len(group_2)

# %%
group_2 = flux_site.copy()
drop_idx = []
for idx, row in group_2.iterrows():
    if row['site_id'] in group_1:
        drop_idx.append(idx)

# %%
group_2 = group_2.drop(drop_idx)

# %%
group_2 = group_2.drop(drop_idx).reset_index()
group_2 = group_2.drop(['index'],axis=1)
group_2
# Out:
#     site_id                        SITE_NAME start year end year     MAP  \
# 0    AR-SLu                         San Luis       2009     2011   400.0
# 1    AU-ASM                    Alice Springs       2010     2014 -9999.0
# 2    AU-Ade                   Adelaide River       2007     2009 -9999.0
# 3    AU-Cpr                         Calperum       2010     2014 -9999.0
# 4    AU-Cum                 Cumberland Plain       2012     2014 -9999.0
# ..      ...                              ...        ...      ...     ...
# 125  US-Wi6            Pine barrens #1 (PB1)       2002     2003 -9999.0
# 126  US-Wi7         Red pine clearcut (RPCC)       2005     2005 -9999.0
# 127  US-Wi8    Young hardwood clearcut (YHW)       2002     2002 -9999.0
# 128  US-Wi9            Young Jack pine (YJP)       2004     2005 -9999.0
# 129  US-Wkg  Walnut Gulch Kendall Grasslands       2004     2014   407.0
#
#        COUNTRY IGBP  LOCATION_LAT  LOCATION_LONG  UTC_OFFSET  ... VPD_F    P  \
# 0    Argentina   MF    -33.464800     -66.459800        -3.0  ...   hPa   mm
# 1    Australia  SAV    -22.283000     133.249000         9.5  ...   hPa   mm
# 2    Australia  WSA    -13.076900     131.117800         9.5  ...   hPa  NaN
# 3    Australia  SAV    -34.002100     140.589100         9.5  ...   hPa   mm
# 4    Australia  EBF    -33.615180     150.723620        10.0  ...   hPa   mm
# ..         ...  ...           ...            ...         ...  ...   ...  ...
# 125        USA  OSH     46.624889     -91.298222        -6.0  ...   hPa   mm
# 126        USA  OSH     46.649111     -91.069278        -6.0  ...   hPa   mm
# 127        USA  DBF     46.722333     -91.252417        -6.0  ...   hPa   mm
# 128        USA  ENF     46.618778     -91.081444        -6.0  ...   hPa   mm
# 129        USA  GRA     31.736500    -109.941900        -7.0  ...   hPa   mm
#
#     P_F   WS_F RH      NEE_VUT_REF  RECO_NT_VUT_REF   GPP_NT_VUT_REF  \
# 0    mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 1    mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 2    mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 3    mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 4    mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# ..   ..    ... ..              ...              ...              ...
# 125  mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 126  mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 127  mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 128  mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 129  mm  m s-1  %  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
#
#      RECO_DT_VUT_REF   GPP_DT_VUT_REF
# 0    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 1    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 2    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 3    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 4    µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# ..               ...              ...
# 125  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 126  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 127  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 128  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
# 129  µmolCO2 m-2 s-1  µmolCO2 m-2 s-1
#
# [130 rows x 23 columns]

# %%
group_2.to_csv('group_2_site_info.csv',float_format='%.5f', index=False)

# %%
# Group 3, SRDB data except related to Flux sites

# %%
group3 = srdb_data.copy()

# %%
group3 = group3.drop(srdb_group1)
group3
# Out:
#        Record_number  Entry_date  Study_number         Author  \
# 1                2.0  2008-09-26          2534  Bond-Lamberty
# 2                3.0  2008-09-26          2534  Bond-Lamberty
# 8                9.0  2008-09-26          2534  Bond-Lamberty
# 9               10.0  2008-09-26          2534  Bond-Lamberty
# 12              13.0  2008-09-26          2534  Bond-Lamberty
# ...              ...         ...           ...            ...
# 10361        10425.0  2020-04-13         11965        Ivanov
# 10362        10426.0  2020-04-13         11965        Ivanov
# 10363        10427.0  2020-04-13         11966        Ivanov
# 10364        10428.0  2020-04-14         12000       Yuzbekov
# 10365        10429.0  2020-04-14         12000       Yuzbekov
#
#       Duplicate_record Quality_flag Contributor  Country     Region  \
# 1                  NaN          Q02         BBL   Canada   Manitoba
# 2                  NaN          Q02         BBL   Canada   Manitoba
# 8                  NaN          Q02         BBL   Canada   Manitoba
# 9                  NaN          Q02         BBL   Canada   Manitoba
# 12                 NaN          Q02         BBL   Canada   Manitoba
# ...                ...          ...         ...      ...        ...
# 10361              NaN          NaN          NK   Russia  Far East
# 10362              NaN          NaN          NK   Russia  Far East
# 10363              NaN          NaN          NK  Russia   Far East
# 10364              NaN          NaN          NK  Russia   Novgorod
# 10365              NaN          NaN          NK  Russia   Novgorod
#
#               Site_name  ...    BA  C_veg_total    C_AG   C_BG   C_CR   C_FR  \
# 1      BOREAS NSA-D1995  ...   0.5        160.0    90.0   70.0   40.0   30.0
# 2      BOREAS NSA-D1989  ...   0.0        520.0   400.0  120.0   70.0   50.0
# 8      BOREAS NSA-W1995  ...   0.0        550.0   100.0  450.0  300.0  150.0
# 9      BOREAS NSA-W1989  ...   0.0        740.0   350.0  390.0  260.0  130.0
# 12     BOREAS NSA-W1930  ...  20.3       3880.0  3400.0  480.0  340.0  140.0
# ...                 ...  ...   ...          ...     ...    ...    ...    ...
# 10361        Primorskii  ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10362        Primorskii  ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10363               NaN  ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10364           Valday   ...   NaN          NaN     NaN    NaN    NaN    NaN
# 10365           Valday   ...   NaN          NaN     NaN    NaN    NaN    NaN
#
#       C_litter C_soilmineral  C_soildepth  \
# 1          NaN       41800.0         70.0
# 2          NaN       41800.0         70.0
# 8          NaN           NaN          NaN
# 9          NaN           NaN          NaN
# 12         NaN           NaN          NaN
# ...        ...           ...          ...
# 10361      NaN           NaN          NaN
# 10362      NaN           NaN          NaN
# 10363      NaN           NaN          NaN
# 10364      NaN           NaN          NaN
# 10365      NaN           NaN          NaN
#
#                                                    Notes
# 1      LAI from Bond-Lamberty (2002); C from Wang (20...
# 2      LAI from Bond-Lamberty (2002); C from Wang (20...
# 8      LAI from Bond-Lamberty (2002); C from Wang (20...
# 9      LAI from Bond-Lamberty (2002); C from Wang (20...
# 12     LAI from Bond-Lamberty (2002); C from Wang (20...
# ...                                                  ...
# 10361                                                NaN
# 10362                                                NaN
# 10363                                                NaN
# 10364                                                NaN
# 10365                                                NaN
#
# [9835 rows x 85 columns]

# %%
group3.to_csv('group3_SRDB.csv',float_format='%.5f', index=False)

# %% [raw]
# _pd.to_csv('duplicate_site_SRDB_values.csv', float_format='%.5f', index=False)

# %% [raw]
# pd_loc['Lat_min'].describe(), pd_loc['Long_min'].describe()

# %% [raw]
# pd_loc[pd_loc['Lat_min']<= 0.1].count()

# %% [raw]
# for index, row in pd_loc.iterrows():
#     lat_min = row['Lat_min']
#     _location[_location[]]

# %%
row
